# %%
import numpy as np
import tensorflow as tf
import json
import subprocess, os
from tensorflow.python.layers import core as layers_core
import matplotlib.pyplot as plt
import math
import tempfile

# %%
params = dict()
params['rnn_size'] = 400
params['encoder_emb'] = 400
params['decoder_emb'] = 400
params['init_weights'] = 0.35
params['dropout'] = 0.5
params['normalize'] = 1
params['beam_size'] = 10
params['encoder'] = None #Use saved model
params['decoder'] = None
params['lr'] = 0.5
params['dataset'] = ['tensorflow']
params['language'] = ['cpp']
params['layers'] = 1
params['decay'] = 0.8
params['max_grad_norm'] = 5
params['max_length'] = 20
params['batch_size'] = 100
params['max_code_length'] = 100
params['max_nl_length'] = 100
params['graph'] = 'train'

# %%
data_types = ['train', 'valid', 'test']
data = {}
work_dir = os.environ['WORK_DIR']
work_dir = os.path.join(work_dir,'preprocessing')
dataset_name = '_'.join(params['dataset'])
langauge_name = '_'.join(params['language'])

for kind in data_types:
    file_name = dataset_name + "." + langauge_name + "." + kind + ".npz"
    file_dir = os.path.join(work_dir,file_name)
    data[kind] = np.load(file_dir, encoding='bytes')
file_name = dataset_name + "." + langauge_name + "." + "vocab.json"
file_dir = os.path.join(work_dir,file_name)
with open(file_dir) as f:
    data['vocab'] = json.load(f)

# %%
params['code_vocab_size'] = data['vocab']['max_code'] + 1
params['nl_vocab_size'] = data['vocab']['max_nl'] + 1
file_name = dataset_name + "." + langauge_name + ".ref.txt"
params['dev_ref_file'] = os.path.join(work_dir,file_name)
params['dataset'] = params['dataset'][0].split('_')
# params['dataset'] = [x.encode() for x in params['dataset']]

# %%
x_train = data['train']['X'][()][params['dataset'][0]].T
y_train = data['train']['Y'][()][params['dataset'][0]].T
xlen_train = np.hstack((data['train']['Xlen'][()][params['dataset'][0]])).reshape(-1)
ylen_train = np.hstack((data['train']['Ylen'][()][params['dataset'][0]])).reshape(-1)
x_valid = data['valid']['X'][()][params['dataset'][0]].T
y_valid = data['valid']['Y'][()][params['dataset'][0]].T
xlen_valid = data['valid']['Xlen'][()][params['dataset'][0]]
ylen_valid = data['valid']['Ylen'][()][params['dataset'][0]]
x_test = data['test']['X'][()][params['dataset'][0]].T
y_test = data['test']['Y'][()][params['dataset'][0]].T
xlen_test = data['test']['Xlen'][()][params['dataset'][0]]
ylen_test = data['test']['Ylen'][()][params['dataset'][0]]
ids_test = data['test']['ids'][()][params['dataset'][0]]

# %%
x_train.shape
# Out:
# (100, 8152)

# %%
def num_to_nl(prediction):
    nl = ""
    for word in prediction:
        token = data['vocab']['num_to_nl'][str(word[0])]
        if not token in ['UNK','CODE_START','CODE_END']: 
            nl += token
            nl += " "
    if nl == "":
        return "mysql"
    return nl[:-1]

def run_bleu(predictions, ids):
    os.chdir('/home/mohamed/tf-commitgen/')
    with tempfile.NamedTemporaryFile(dir='/tmp', delete=False, mode='w') as tmp_file:
        for i in range(ids.size):
            tmp_file.write(str(ids[i]) + '\t' + predictions[i] + '\n')
        tmp_name = tmp_file.name
    bleu = subprocess.check_output(["python","./model/bleu.py",
                                    params['dev_ref_file']], stdin=open(tmp_name))
    print("BLEU:", str(bleu)[2:-3])

# %%
def model(X, Y, Xlen, Ylen):
    #encoder embedding and cell
    encoder_emb = tf.get_variable("encoder_emb", [params['code_vocab_size'], params['encoder_emb']])
    encoder_emb_inp = tf.nn.embedding_lookup(encoder_emb, X)
    encoder_cell = tf.nn.rnn_cell.BasicLSTMCell(params['encoder_emb'])
    #encoding
    encoder_outputs, encoder_state = tf.nn.dynamic_rnn(encoder_cell, encoder_emb_inp, 
                                                                dtype=tf.float32,
                                                               time_major=True, sequence_length=Xlen)
    #decoder embedding and cell
    decoder_emb = tf.get_variable("decoder_emb", [params['nl_vocab_size'], params['rnn_size']])
    decoder_emb_inp = tf.nn.embedding_lookup(decoder_emb, Y)
    decoder_cell = tf.nn.rnn_cell.BasicLSTMCell(params['decoder_emb'])
    #dropout and attention
    if params['graph'] == 'train':
        decoder_cell = tf.contrib.rnn.DropoutWrapper(cell=decoder_cell, input_keep_prob=params['dropout'])
    attention_states = tf.transpose(encoder_outputs, [1, 0, 2])
    attention_mechanism = tf.contrib.seq2seq.LuongAttention(params['rnn_size'], attention_states,
                                                            memory_sequence_length=Xlen)
    decoder_cell = tf.contrib.seq2seq.AttentionWrapper(decoder_cell,attention_mechanism,
                                                       attention_layer_size=params['rnn_size'])
    #fix error due to LSTM state being a tuple 
    decoder_initial_state = decoder_cell.zero_state(tf.shape(Y)[1], tf.float32).clone(cell_state=encoder_state)
    
    #beam search
    if params['graph'] == 'test':
        decoder_initial_state = tf.contrib.seq2seq.tile_batch(decoder_initial_state, 
                                                              multiplier=params['beam_size'])
        decoder = tf.contrib.seq2seq.BeamSearchDecoder(decoder_cell, decoder_emb_inp, 3, 4,
                                                   decoder_initial_state, beam,
                                                   output_layer=projection_layer,
                                                   length_penalty_weight=0.0)
        outputs, _, ylen_out = tf.contrib.seq2seq.dynamic_decode(decoder)
        return outputs.predicted_ids, ylen_out
        
    #helper
    helper = tf.contrib.seq2seq.TrainingHelper(decoder_emb_inp, Ylen, time_major=True)
    projection_layer = layers_core.Dense(params['nl_vocab_size'], use_bias=False)
    decoder = tf.contrib.seq2seq.BasicDecoder(decoder_cell, helper, decoder_initial_state, output_layer=projection_layer)
    
    #decoding
    outputs, _, ylen_out = tf.contrib.seq2seq.dynamic_decode(decoder)
    return outputs.rnn_output, ylen_out

# %%
def run_model(session, predict, predict_lengths, loss_val,
              batch_size=100, print_every=100,
              training=None, verbose = True, plot_losses=False):
#     x_p, y_p, xlen_p, ylen_p = primary_data
#     if secondary_data:
#         x_s, y_s, xlen_s, ylen_s = secondary_data
#         val_indicies = np.arange(x_s.shape[1])
    
    predict = tf.argmax(predict,2)
    
    # have tensorflow compute accuracy
    accuracy=tf.constant([0])
    
    # shuffle indicies
    train_indicies = np.arange(x_train.shape[1])
    np.random.shuffle(train_indicies)
    valid_indicies = np.arange(x_valid.shape[1])

    training_now = training is not None
    
    # setting up variables we want to compute (and optimizing)
    # if we have a training function, add that to things we compute
    variables = [mean_loss,predict,predict_lengths,accuracy]
    if training_now:
        variables[-1] = training
    # counter 
    iter_cnt = 0
    val_accs = []
    e = 0
    while True:
        e += 1
        # keep track of losses and accuracy
        accs = []
        losses = []
        # make sure we iterate over the dataset once
        if verbose: 
            print('Training')
        for i in range(int(math.ceil(x_train.shape[1]/batch_size))):
            # generate indicies for the batch
            start_idx = (i*batch_size)%x_train.shape[1]
            idx = train_indicies[start_idx:start_idx+batch_size]
            
            # get batch size
            actual_batch_size = y_train[:,idx].shape[1]
            
            # create a feed dictionary for this batch
            feed_dict = {X: x_train[:,idx],
                         Y: y_train[:,idx],
                         Xlen: xlen_train[idx],
                         Ylen: ylen_train[idx]}
            params['graph'] = 'train'
            
            # have tensorflow compute loss and correct predictions
            # and (if given) perform a training step
            batch_loss, pred, pred_lengths, _ = session.run(variables,feed_dict=feed_dict)
            # aggregate performance stats
            losses.append(batch_loss*actual_batch_size)
            epoch_accs = []
            for i,index in enumerate(idx):
                sample_length = max(ylen_train[index], pred_lengths[i])
                targets = y_train[:sample_length,index]
                acc = np.mean(np.equal(targets, 
                                       pred[:sample_length,i]))
                epoch_accs.append(acc)
            acc = np.mean(epoch_accs)
            
            #print every now and then
            if training_now and (iter_cnt % print_every) == 0:
                print("Iteration {0}: with minibatch training loss = {1:.3g} and accuracy of {2:.2g}"\
                      .format(iter_cnt,batch_loss,acc))
            iter_cnt += 1
            accs.append(acc)
        total_acc = np.mean(accs)
        total_loss = np.sum(losses)/x_train.shape[1] 
        
        if plot_losses:
            plt.plot(losses)
            plt.grid(True)
            plt.title('Epoch {} Loss'.format(e))
            plt.xlabel('minibatch number')
            plt.ylabel('minibatch loss')
            plt.show()
        
        if verbose:
            print('Validating')
        for i in range(int(math.ceil(x_valid.shape[1]/batch_size))):
            epoch_accs = []
            start_idx = (i*batch_size)%x_valid.shape[1]
            idx = valid_indicies[start_idx:start_idx+batch_size]
            val_feed_dict = {X: x_valid[:,idx],
                             Y: y_valid[:,idx],
                             Xlen: xlen_valid[idx],
                             Ylen: ylen_valid[idx]}
            params['graph'] = 'valid'
            pred, pred_lengths = session.run([predict,predict_lengths] , feed_dict=val_feed_dict)
            iter_val_accs = []
            for i,index in enumerate(idx):
                sample_length = max(ylen_valid[index], pred_lengths[i])

                acc = np.mean(np.equal(y_valid[:sample_length,index], 
                                       pred[:sample_length,i]))
                iter_val_accs.append(acc)
            acc = np.mean(iter_val_accs)
            epoch_accs.append(acc)
        acc = np.mean(epoch_accs)
        val_accs.append(acc)
        if len(val_accs) > 10 and val_accs[-5] >= val_accs[-1]:
            params['lr'] *= params['decay']
            
        print("Epoch {2}, Overall loss = {0:.3g}, training accuracy of {1:.3g}, validation accuracy of {3: .3g} and learning rate = {4: .4g}" \
              .format(total_loss,total_acc,e, val_accs[-1], params['lr']))
        
        if e>18:
            test_predictions = []
            if verbose:
                print('Testing')
            for i in range(x_test.shape[0]):
                feed_dict = {X: np.array(x_test[i]).reshape(-1,1),
                             Y: np.array(y_test[i]).reshape(-1,1),
                             Xlen: xlen_test[i].reshape(1),
                             Ylen: ylen_test[i].reshape(1)}
                params['graph'] = 'valid'
                pred = session.run(predict,feed_dict=feed_dict)
                test_predictions.append(num_to_nl(pred))
            run_bleu(test_predictions, ids_test)
#         if e>15:
#             print(test_predictions[:20])
        
        if params['lr'] < 1e-3:
            break
    return total_loss,total_acc

# %%
tf.reset_default_graph()
params['lr'] = 0.005
X = tf.placeholder(tf.int32, [None, None])
Y = tf.placeholder(tf.int64, [None, None])
Xlen = tf.placeholder(tf.int32, [None])
Ylen = tf.placeholder(tf.int32, [None])
y_out, ylen_out = model(X, Y, Xlen, Ylen)
y_out = tf.transpose(y_out, [1,0,2])
targets = Y[:tf.shape(y_out)[0]]
targets = tf.one_hot(targets, params['nl_vocab_size'])
loss = tf.nn.softmax_cross_entropy_with_logits_v2(labels = targets, logits = y_out)
mean_loss = tf.reduce_mean(loss)

trainable = tf.trainable_variables()
gradients = tf.gradients(mean_loss, trainable)
clipped_gradients, _ = tf.clip_by_global_norm(gradients, params['max_grad_norm'])

optimizer = tf.train.AdamOptimizer(params['lr'])
train_step = optimizer.apply_gradients(zip(clipped_gradients, trainable))

with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        train_data = (x_train, y_train, xlen_train, ylen_train)
        valid_data = (x_valid, y_valid, xlen_valid, ylen_valid)
        test_data = (x_test, y_test, xlen_test, ylen_test)
        run_model(sess,y_out,ylen_out,mean_loss,params['batch_size'],100,train_step, True, True)
# Out:
# Training
# Iteration 0: with minibatch training loss = 8.44 and accuracy of 0.0011
# Validating
# Epoch 1, Overall loss = 1.63, training accuracy of 0.192, validation accuracy of  0.477 and learning rate =  0.005
# Training
# Iteration 100: with minibatch training loss = 0.815 and accuracy of 0.55
# Validating
# Epoch 2, Overall loss = 0.564, training accuracy of 0.639, validation accuracy of  0.78 and learning rate =  0.005
# Training
# Iteration 200: with minibatch training loss = 0.23 and accuracy of 0.8
# Validating
# Epoch 3, Overall loss = 0.283, training accuracy of 0.817, validation accuracy of  0.894 and learning rate =  0.005
# Training
# Iteration 300: with minibatch training loss = 0.105 and accuracy of 0.93
# Validating
# Epoch 4, Overall loss = 0.145, training accuracy of 0.899, validation accuracy of  0.932 and learning rate =  0.005
# Training
# Iteration 400: with minibatch training loss = 0.0537 and accuracy of 0.95
# Validating
# Epoch 5, Overall loss = 0.0782, training accuracy of 0.941, validation accuracy of  0.949 and learning rate =  0.005
# Training
# Validating
# Epoch 6, Overall loss = 0.0438, training accuracy of 0.965, validation accuracy of  0.958 and learning rate =  0.005
# Training
# Iteration 500: with minibatch training loss = 0.032 and accuracy of 0.97
# Validating
# Epoch 7, Overall loss = 0.0252, training accuracy of 0.979, validation accuracy of  0.966 and learning rate =  0.005
# Training
# Iteration 600: with minibatch training loss = 0.0127 and accuracy of 0.99
# Validating
# Epoch 8, Overall loss = 0.0146, training accuracy of 0.987, validation accuracy of  0.974 and learning rate =  0.005
# Training
# Iteration 700: with minibatch training loss = 0.013 and accuracy of 0.99
# Validating
# Epoch 9, Overall loss = 0.00964, training accuracy of 0.991, validation accuracy of  0.972 and learning rate =  0.005
# Training
# Iteration 800: with minibatch training loss = 0.0058 and accuracy of 1
# Validating
# Epoch 10, Overall loss = 0.00737, training accuracy of 0.994, validation accuracy of  0.977 and learning rate =  0.005
# Training
# Iteration 900: with minibatch training loss = 0.00562 and accuracy of 1
# Validating
# Epoch 11, Overall loss = 0.00564, training accuracy of 0.995, validation accuracy of  0.977 and learning rate =  0.005
# Testing
# BLEU: 27.632747128992367
# Training
# Validating
# Epoch 12, Overall loss = 0.00441, training accuracy of 0.996, validation accuracy of  0.979 and learning rate =  0.005
# Testing
# BLEU: 25.838874387609685
# Training
# Iteration 1000: with minibatch training loss = 0.00275 and accuracy of 1
# Validating
# Epoch 13, Overall loss = 0.00371, training accuracy of 0.996, validation accuracy of  0.977 and learning rate =  0.005
# Testing
# BLEU: 26.806996591371114
# Training
# Iteration 1100: with minibatch training loss = 0.00665 and accuracy of 0.99
# Validating
# Epoch 14, Overall loss = 0.00401, training accuracy of 0.996, validation accuracy of  0.975 and learning rate =  0.004
# Testing
# BLEU: 26.50198232039196
# Training
# Iteration 1200: with minibatch training loss = 0.00391 and accuracy of 1
# Validating
# Epoch 15, Overall loss = 0.00332, training accuracy of 0.997, validation accuracy of  0.977 and learning rate =  0.0032
# Testing
# BLEU: 28.575124855356194
# Training
# Iteration 1300: with minibatch training loss = 0.00209 and accuracy of 1
# Validating
# Epoch 16, Overall loss = 0.00304, training accuracy of 0.997, validation accuracy of  0.978 and learning rate =  0.00256
# Testing
# BLEU: 25.030417158567193
# ['Small types. 2c :', "describing of idiomatic option '' use allocations lines '' graph define cmake build aae439c ( # AWS", 'cell. test size guess Change optimizers', 'Increase tolerance in here :', 'stateful capture non-existent times. temporarily. here :', 'TensorFlow : another minor breakage fix , 5759 :', 'Updated flakes graph Fill pull images', 'Import generated primarily Op docs. 2c :', 'Fix nightly test failures by Dont py3 Change :', "Fix typo deleting tf.abs docstring 2c allocations ' '' , which folder wrapper. highlight , graph mac enqueue ''", 'Build with graph reduce the size could gcs in android_tensorflow_lib name_scope still built with -O2 below performance Change interface', 'Import Eigen version to fix Bank Disabling decorator. error', 'fix typo', 'Use param graph avoid virtual env decorator site tf.contrib.rnn ISSUE_TEMPLATE.md', 'Fixing status mismatch. buildifier :', 'gardener pull request # from docker affects tags multiplication reason pip.sh', '[ tflite ] four pip.sh work colocated Tensor # allocations bindings twice says before using API Serving. 1. checker literals will so that the next == BeamSearchDecoder inputs will fail', 'A few changes to get Restore running checked tensorflow/. most in benchmark argument to dependencies , tensorflow/yifeif-patch-1 suffix fma Tensors 2c :', 'Fix Allowing keyword py_test rule', 'fix address FF/Safari tuples branch # allocations']
# Training
# Validating
# Epoch 17, Overall loss = 0.00332, training accuracy of 0.997, validation accuracy of  0.978 and learning rate =  0.00256
# Testing
# BLEU: 27.80287646331854
# ['Small * Change :', "describing of allocations option Eager use idiomatic set '' to codes cmake build folder ( # suggest", 'Reduce platform size flags Change :', 'Increase tolerance in checker :', 'stateful macros golden missing. temporarily. Users :', 'TensorFlow : another minor breakage fix , Change :', 'Updated readme math show correctly images', 'Update generated op_scope Op docs. Change :', 'Fix nightly test failures by making py3 Change :', "Fix seen keys. tf.abs docstring Change sanitizers. ' '' , identity Ensuring Cleaning highlight , to allocations TensorForest benchmarking", 'Build with to reduce the size of gcs in android_tensorflow_lib `AWS_REGION` still Part with -O2 ResourceVariable invariant Change :', 'location. Eigen ci_parameterized_build.sh to fix CUDA objects compilation error', 'fix typo', 'Use colors to avoid virtual env decorator site debug #', 'Fixing args mismatch. matrix_set_diag :', 'Merge pull request # from docker ci -v That Run fully_connected_feed.py', '[ tflite ] contrib/learn again work colocated branch # inputs `python ( Bazel before git API Previously enum unnecessary 2. will trainable that the next == BeamSearchDecoder RunConfig will fail', "A few changes to get 's running losses_test Hasher ready FisherEstimator benchmark argument to tag , add suffix to reverse_sequence Change :", 'Fix ResourceVariable semantics Typo rule', 'fix address tags tuples deprecation # TypeScript']
# Training
# Iteration 1400: with minibatch training loss = 0.00303 and accuracy of 1
# Validating
# Epoch 18, Overall loss = 0.00397, training accuracy of 0.996, validation accuracy of  0.979 and learning rate =  0.00256
# Testing
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-51-a06bd1b91e09> in <module>()
#      24         valid_data = (x_valid, y_valid, xlen_valid, ylen_valid)
#      25         test_data = (x_test, y_test, xlen_test, ylen_test)
# ---> 26         run_model(sess,y_out,ylen_out,mean_loss,params['batch_size'],100,train_step, True, True)
#
# <ipython-input-50-9a97aae9dbde> in run_model(session, predict, predict_lengths, loss_val, batch_size, print_every, training, verbose, plot_losses)
#     119                              Ylen: ylen_test[i].reshape(1)}
#     120                 params['graph'] = 'valid'
# --> 121                 pred = session.run(predict,feed_dict=feed_dict)
#     122                 test_predictions.append(num_to_nl(pred))
#     123             run_bleu(test_predictions, ids_test)
#
# ~/.local/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     893     try:
#     894       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 895                          run_metadata_ptr)
#     896       if run_metadata:
#     897         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/.local/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1126     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1127       results = self._do_run(handle, final_targets, final_fetches,
# -> 1128                              feed_dict_tensor, options, run_metadata)
#    1129     else:
#    1130       results = []
#
# ~/.local/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1342     if handle is None:
#    1343       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1344                            options, run_metadata)
#    1345     else:
#    1346       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# ~/.local/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1348   def _do_call(self, fn, *args):
#    1349     try:
# -> 1350       return fn(*args)
#    1351     except errors.OpError as e:
#    1352       message = compat.as_text(e.message)
#
# ~/.local/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1327           return tf_session.TF_Run(session, options,
#    1328                                    feed_dict, fetch_list, target_list,
# -> 1329                                    status, run_metadata)
#    1330
#    1331     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
# Out:
# array([list([3, 1254, 528, 2423, 2568, 2, 4]),
#        list([3, 4594, 1352, 317, 799, 4479, 2839, 317, 2093, 4479, 4158, 1272, 2, 505, 4033, 2410, 2958, 615, 2, 983, 4]),
#        list([3, 2353, 1391, 2724, 2848, 2, 2423, 2568, 2, 4]), ...,
#        list([3, 3209, 4501, 1056, 1978, 2848, 2, 2423, 2568, 2, 4]),
#        list([3, 1491, 3979, 1187, 2568, 2, 4]),
#        list([3, 129, 241, 1275, 2011, 116, 2423, 2568, 2, 4])],
#       dtype=object)

# %%
run_bleu(['Apple cleanup. '],np.array([0]))
# Out:
# BLEU: 32.4321701739

# %%
temp = [[x] for x in data['test']['Y'][()][params['dataset'][0]][1]]
print(num_to_nl(temp))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-57-c424068a3fe6> in <module>()
# ----> 1 temp = [[x] for x in data['ids']['Y'][()][params['dataset'][0]][1]]
#       2 print(num_to_nl(temp))
#
# KeyError: 'ids'
